# %% [markdown]
# <a href="https://colab.research.google.com/github/mandarina125/Desafio_leer_tabla/blob/main/Desaf%C3%ADo_leer_una_tabla_de_una_p%C3%A1gina_web.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Es el momento de poner a prueba los conocimientos desarrollados durante la clase.
#
# Vanessa es una científica de datos que está haciendo algunos análisis con datos ambientales. Está desarrollando un proyecto para evaluar el impacto ambiental de las actividades humanas en diferentes países del mundo, pero para ello necesita estimaciones de población de esos países. Al buscar en Internet, encontró una tabla de estimaciones de población en un artículo de la página de Wikipedia. https://es.wikipedia.org/wiki/Anexo:Pa%C3%ADses_y_territorios_dependientes_por_poblaci%C3%B3n
#
# Al igual que Vanessa, tu desafío es obtener un DataFrame de la tabla que contiene la información del número de habitantes de cada país.

# %% [markdown]
# Se importa la libreria panda

# %%
import pandas as pd

# %% [markdown]
# Se carga el archivo con la extensión html , se lee y se guarda en la variable datos_paises.

# %%
datos_paises = pd.read_html("Anexo_Países.html")

# %% [markdown]
# Se muestro la lectura de la variable datos_paises.  Y se extrae la tabla principal que contiene la cantidad de población según el país.

# %%
datos_paises[0].head(5)
# Out:
#    N.º País (o territorio dependiente)  \
# 0   40                      Afganistán
# 1  223               Åland (Finlandia)
# 2  146                         Albania
# 3   19                        Alemania
# 4  203                         Andorra
#
#   Proyección exponencial de la población al 1/7/2025[7]​ Total mun- dial (%)  \
# 0                                         36 931 000                     046
# 1                                             31 000                     000
# 2                                          2 348 000                     003
# 3                                         83 742 000                     104
# 4                                             88 000                     000
#
#   Cambio medio anual (%)[8]​ Cambio absoluto anual promedio  \
# 0                        346                      1 279 000
# 1                        038                              0
# 2                       -133                        -31 000
# ...

# %% [markdown]
# Tamaño de la lista

# %%
len(datos_paises)
# Out:
# 7

# %%
tabla_final = datos_paises[0]

# %%
tabla_final.head(5)
# Out:
#    N.º País (o territorio dependiente)  \
# 0   40                      Afganistán
# 1  223               Åland (Finlandia)
# 2  146                         Albania
# 3   19                        Alemania
# 4  203                         Andorra
#
#   Proyección exponencial de la población al 1/7/2025[7]​ Total mun- dial (%)  \
# 0                                         36 931 000                     046
# 1                                             31 000                     000
# 2                                          2 348 000                     003
# 3                                         83 742 000                     104
# 4                                             88 000                     000
#
#   Cambio medio anual (%)[8]​ Cambio absoluto anual promedio  \
# 0                        346                      1 279 000
# 1                        038                              0
# 2                       -133                        -31 000
# ...

# %% [markdown]
# Exportar la tabla a un archivo HTML

# %%
tabla_final.to_html("tabla_final.html")
